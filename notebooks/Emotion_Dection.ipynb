# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import os

# %%
train_dir = "../data/vision/Dataset/train"
test_dir = "../data/vision/Dataset/test"

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 6 classes.
# Found 1432 images belonging to 6 classes.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(6, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model.weights.h5',   # ✅ FIXED
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=30,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.1917 - loss: 2.7404
# Epoch 1: val_accuracy improved from None to 0.24581, saving model to model.weights.h5
#
# Epoch 1: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 135s 363ms/step - accuracy: 0.2022 - loss: 2.6116 - val_accuracy: 0.2458 - val_loss: 1.8570
# Epoch 2/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.2309 - loss: 2.3313
# Epoch 2: val_accuracy improved from 0.24581 to 0.31285, saving model to model.weights.h5
#
# Epoch 2: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 132s 368ms/step - accuracy: 0.2382 - loss: 2.2656 - val_accuracy: 0.3128 - val_loss: 1.6747
# Epoch 3/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.2613 - loss: 2.1234
# Epoch 3: val_accuracy improved from 0.31285 to 0.35824, saving model to model.weights.h5
#
# Epoch 3: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 129s 359ms/step - accuracy: 0.2685 - loss: 2.0937 - val_accuracy: 0.3582 - val_loss: 1.6258
# Epoch 4/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.2858 - loss: 2.0036
# Epoch 4: val_accuracy improved from 0.35824 to 0.37430, saving model to model.weights.h5
#
# Epoch 4: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 131s 364ms/step - accuracy: 0.2881 - loss: 1.9894 - val_accuracy: 0.3743 - val_loss: 1.5763
# Epoch 5/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.3154 - loss: 1.8878
# Epoch 5: val_accuracy improved from 0.37430 to 0.40293, saving model to model.weights.h5
#
# Epoch 5: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 362ms/step - accuracy: 0.3217 - loss: 1.8645 - val_accuracy: 0.4029 - val_loss: 1.5405
# Epoch 6/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.3305 - loss: 1.8083
# Epoch 6: val_accuracy improved from 0.40293 to 0.43017, saving model to model.weights.h5
#
# Epoch 6: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 363ms/step - accuracy: 0.3377 - loss: 1.7933 - val_accuracy: 0.4302 - val_loss: 1.4588
# Epoch 7/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.3578 - loss: 1.7475
# Epoch 7: val_accuracy improved from 0.43017 to 0.45251, saving model to model.weights.h5
#
# Epoch 7: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 361ms/step - accuracy: 0.3604 - loss: 1.7357 - val_accuracy: 0.4525 - val_loss: 1.4103
# Epoch 8/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.3680 - loss: 1.6843
# Epoch 8: val_accuracy improved from 0.45251 to 0.47765, saving model to model.weights.h5
#
# Epoch 8: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 363ms/step - accuracy: 0.3767 - loss: 1.6592 - val_accuracy: 0.4777 - val_loss: 1.3446
# Epoch 9/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.3848 - loss: 1.6183
# Epoch 9: val_accuracy improved from 0.47765 to 0.48045, saving model to model.weights.h5
#
# Epoch 9: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 129s 360ms/step - accuracy: 0.3904 - loss: 1.6118 - val_accuracy: 0.4804 - val_loss: 1.3204
# Epoch 10/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.4021 - loss: 1.5652
# Epoch 10: val_accuracy improved from 0.48045 to 0.49232, saving model to model.weights.h5
#
# Epoch 10: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 131s 364ms/step - accuracy: 0.4082 - loss: 1.5489 - val_accuracy: 0.4923 - val_loss: 1.2985
# Epoch 11/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.4244 - loss: 1.5058
# Epoch 11: val_accuracy improved from 0.49232 to 0.52654, saving model to model.weights.h5
#
# Epoch 11: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 131s 364ms/step - accuracy: 0.4265 - loss: 1.4973 - val_accuracy: 0.5265 - val_loss: 1.2592
# Epoch 12/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.4404 - loss: 1.4574
# Epoch 12: val_accuracy improved from 0.52654 to 0.53352, saving model to model.weights.h5
#
# Epoch 12: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 362ms/step - accuracy: 0.4405 - loss: 1.4601 - val_accuracy: 0.5335 - val_loss: 1.2129
# Epoch 13/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.4580 - loss: 1.4092
# Epoch 13: val_accuracy did not improve from 0.53352
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 363ms/step - accuracy: 0.4618 - loss: 1.4041 - val_accuracy: 0.5314 - val_loss: 1.2164
# Epoch 14/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.4638 - loss: 1.3760
# Epoch 14: val_accuracy improved from 0.53352 to 0.55517, saving model to model.weights.h5
#
# Epoch 14: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 133s 370ms/step - accuracy: 0.4690 - loss: 1.3660 - val_accuracy: 0.5552 - val_loss: 1.1787
# Epoch 15/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.4837 - loss: 1.3401
# Epoch 15: val_accuracy improved from 0.55517 to 0.55796, saving model to model.weights.h5
#
# Epoch 15: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 131s 365ms/step - accuracy: 0.4834 - loss: 1.3402 - val_accuracy: 0.5580 - val_loss: 1.1574
# Epoch 16/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.4825 - loss: 1.3338
# Epoch 16: val_accuracy improved from 0.55796 to 0.56844, saving model to model.weights.h5
#
# Epoch 16: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 132s 366ms/step - accuracy: 0.4891 - loss: 1.3153 - val_accuracy: 0.5684 - val_loss: 1.1299
# Epoch 17/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.4967 - loss: 1.2949
# Epoch 17: val_accuracy improved from 0.56844 to 0.56983, saving model to model.weights.h5
#
# Epoch 17: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 133s 370ms/step - accuracy: 0.4987 - loss: 1.2929 - val_accuracy: 0.5698 - val_loss: 1.1508
# Epoch 18/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.5156 - loss: 1.2565
# Epoch 18: val_accuracy improved from 0.56983 to 0.57542, saving model to model.weights.h5
#
# Epoch 18: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 136s 379ms/step - accuracy: 0.5182 - loss: 1.2523 - val_accuracy: 0.5754 - val_loss: 1.1130
# Epoch 19/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.5186 - loss: 1.2366
# Epoch 19: val_accuracy improved from 0.57542 to 0.58380, saving model to model.weights.h5
#
# Epoch 19: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 129s 358ms/step - accuracy: 0.5177 - loss: 1.2412 - val_accuracy: 0.5838 - val_loss: 1.0984
# Epoch 20/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.5183 - loss: 1.2355
# Epoch 20: val_accuracy did not improve from 0.58380
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 362ms/step - accuracy: 0.5241 - loss: 1.2258 - val_accuracy: 0.5810 - val_loss: 1.0900
# Epoch 21/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.5387 - loss: 1.2049
# Epoch 21: val_accuracy improved from 0.58380 to 0.59427, saving model to model.weights.h5
#
# Epoch 21: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 361ms/step - accuracy: 0.5374 - loss: 1.2045 - val_accuracy: 0.5943 - val_loss: 1.0629
# Epoch 22/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.5490 - loss: 1.1803
# Epoch 22: val_accuracy improved from 0.59427 to 0.60754, saving model to model.weights.h5
#
# Epoch 22: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 363ms/step - accuracy: 0.5421 - loss: 1.1831 - val_accuracy: 0.6075 - val_loss: 1.0489
# Epoch 23/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.5496 - loss: 1.1661
# Epoch 23: val_accuracy did not improve from 0.60754
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 167s 466ms/step - accuracy: 0.5515 - loss: 1.1673 - val_accuracy: 0.5831 - val_loss: 1.0471
# Epoch 24/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.5562 - loss: 1.1464
# Epoch 24: val_accuracy did not improve from 0.60754
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 168s 467ms/step - accuracy: 0.5542 - loss: 1.1549 - val_accuracy: 0.5859 - val_loss: 1.0796
# Epoch 25/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.5674 - loss: 1.1389
# Epoch 25: val_accuracy did not improve from 0.60754
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 129s 361ms/step - accuracy: 0.5632 - loss: 1.1406 - val_accuracy: 0.6054 - val_loss: 1.0389
# Epoch 26/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.5632 - loss: 1.1333
# Epoch 26: val_accuracy did not improve from 0.60754
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 130s 362ms/step - accuracy: 0.5639 - loss: 1.1374 - val_accuracy: 0.5992 - val_loss: 1.0538
# Epoch 27/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.5765 - loss: 1.1088
# Epoch 27: val_accuracy improved from 0.60754 to 0.62430, saving model to model.weights.h5
#
# Epoch 27: finished saving model to model.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 135s 375ms/step - accuracy: 0.5711 - loss: 1.1189 - val_accuracy: 0.6243 - val_loss: 1.0091
# Epoch 28/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.5746 - loss: 1.1048
# Epoch 28: val_accuracy did not improve from 0.62430
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 147s 409ms/step - accuracy: 0.5783 - loss: 1.1009 - val_accuracy: 0.6194 - val_loss: 1.0079
# Epoch 29/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.5809 - loss: 1.0963
# Epoch 29: val_accuracy did not improve from 0.62430
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 137s 381ms/step - accuracy: 0.5791 - loss: 1.0991 - val_accuracy: 0.6145 - val_loss: 1.0028
# Epoch 30/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.5874 - loss: 1.0868
# Epoch 30: val_accuracy did not improve from 0.62430
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 136s 380ms/step - accuracy: 0.5841 - loss: 1.0863 - val_accuracy: 0.6089 - val_loss: 1.0246

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title("Accuracy Curve")
plt.show()

# %%
model.save("../backend/best_model.keras")
